# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/drive/MyDrive/ML WorkShop /dataset/salary.csv')

# %%
dataset
# Out:
#        age  education.num  capital.gain  hours.per.week income
# 0       90              9             0              40  <=50K
# 1       82              9             0              18  <=50K
# 2       66             10             0              40  <=50K
# 3       54              4             0              40  <=50K
# 4       41             10             0              40  <=50K
# ...    ...            ...           ...             ...    ...
# 32556   22             10             0              40  <=50K
# 32557   27             12             0              38  <=50K
# 32558   40              9             0              40   >50K
# 32559   58              9             0              40  <=50K
# 32560   22              9             0              20  <=50K
#
# [32561 rows x 5 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   education.num   32561 non-null  int64
#  2   capital.gain    32561 non-null  int64
#  3   hours.per.week  32561 non-null  int64
#  4   income          32561 non-null  object
# dtypes: int64(4), object(1)
# memory usage: 1.2+ MB

# %%
dataset.isna().sum()
# Out:
# age               0
# education.num     0
# capital.gain      0
# hours.per.week    0
# income            0
# dtype: int64

# %%
dataset.head(10)
# Out:
#    age  education.num  capital.gain  hours.per.week income
# 0   90              9             0              40  <=50K
# 1   82              9             0              18  <=50K
# 2   66             10             0              40  <=50K
# 3   54              4             0              40  <=50K
# 4   41             10             0              40  <=50K
# 5   34              9             0              45  <=50K
# 6   38              6             0              40  <=50K
# 7   74             16             0              20   >50K
# 8   68              9             0              40  <=50K
# 9   41             10             0              60   >50K

# %%
dataset.iloc[101:201]
# Out:
#      age  education.num  capital.gain  hours.per.week income
# 101   46             16             0              55   >50K
# 102   53             13             0              40   >50K
# 103   50             15             0              30   >50K
# 104   41             15             0              55   >50K
# 105   36             13             0              45   >50K
# ..   ...            ...           ...             ...    ...
# 196   23             13             0              40   >50K
# 197   49              5             0              40   >50K
# 198   27             10             0              40   >50K
# 199   90              9             0              40  <=50K
# 200   68              9             0              30  <=50K
#
# [100 rows x 5 columns]

# %%
dataset.iloc[:,[0,4]]
# Out:
#        age income
# 0       90  <=50K
# 1       82  <=50K
# 2       66  <=50K
# 3       54  <=50K
# 4       41  <=50K
# ...    ...    ...
# 32556   22  <=50K
# 32557   27  <=50K
# 32558   40   >50K
# 32559   58  <=50K
# 32560   22  <=50K
#
# [32561 rows x 2 columns]

# %%
dataset["income"].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()

y = dataset['income']
dataset['income'] = label.fit_transform(y)
label.classes_
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
dataset
# Out:
#        age  education.num  capital.gain  hours.per.week  income
# 0       90              9             0              40       0
# 1       82              9             0              18       0
# 2       66             10             0              40       0
# 3       54              4             0              40       0
# 4       41             10             0              40       0
# ...    ...            ...           ...             ...     ...
# 32556   22             10             0              40       0
# 32557   27             12             0              38       0
# 32558   40              9             0              40       1
# 32559   58              9             0              40       0
# 32560   22              9             0              20       0
#
# [32561 rows x 5 columns]

# %%
x = dataset.iloc[:,:-1].values
x
# Out:
# array([[90,  9,  0, 40],
#        [82,  9,  0, 18],
#        [66, 10,  0, 40],
#        ...,
#        [40,  9,  0, 40],
#        [58,  9,  0, 40],
#        [22,  9,  0, 20]])

# %%
y = dataset.iloc[:,-1].values
y
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (26048, 4)
# (6513, 4)
# (26048,)
# (6513,)

# %%
dataset['age'].min()
# Out:
# 17

# %%
dataset['age'].max()
# Out:
# 90

# %%
dataset['education.num'].min()
# Out:
# 1

# %%
dataset['education.num'].max()
# Out:
# 16

# %%
dataset['capital.gain'].min()
# Out:
# 0

# %%
dataset['capital.gain'].max()
# Out:
# 99999

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=2,metric='minkowski')
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred = knn.predict(x_test)

# %%
# print("accuracy is :",format(knn.score(y_test,y_pred)*100))

# %%
Age = int(input("Enter Age : "))
Education_num = int(input("Enter Education Num : "))
capital_gain = int(input("Enter Capital Gain : "))
working_hours = int(input("Enter Working Hours : "))

newemp = [[Age,Education_num,capital_gain,working_hours]]

result = knn.predict(sc.transform(newemp))

print(result)

if result == 1 :
  print("Employee might have salary above 50k")
else:
  print("Employee might not have salary above 50k")
# Out:
# Enter Age : 60
# Enter Education Num : 40
# Enter Capital Gain : 30
# Enter Working Hours : 20
# [1]
# Employee might have salary aboue 50k

# %%
from sklearn.metrics import confusion_matrix , accuracy_score

cm = confusion_matrix(y_test,y_pred)

print("confusion matrix :")
print(cm)

print("accuracy of : {0}%".format(accuracy_score(y_test,y_pred)*100))
# Out:
# confusion matrix :
# [[4757  219]
#  [1084  453]]
# accuracy of : 79.9938584369722%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data_set = pd.read_csv('/content/drive/MyDrive/ML WorkShop /dataset/users.csv')

# %%
data_set
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 0   15624510    Male   12            19000          0
# 1   15810944    Male   11            20000          0
# 2   15668575  Female    1            43000          0
# 3   15603246  Female   27            57000          0
# 4   15804002    Male   10            76000          0
# ..       ...     ...  ...              ...        ...
# 94  15786993  Female   45            83000          0
# 95  15709441  Female   35            44000          0
# 96  15710257  Female    4            25000          0
# 97  15582492    Male    5           123000          1
# 98  15575694    Male   35            73000          0
#
# [99 rows x 5 columns]

# %%
data_set.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          99 non-null     int64
#  1   Gender           99 non-null     object
#  2   Age              99 non-null     int64
#  3   EstimatedSalary  99 non-null     int64
#  4   Purchased        99 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 4.0+ KB

# %%
data_set.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   12            19000          0
# 1  15810944    Male   11            20000          0
# 2  15668575  Female    1            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   10            76000          0

# %%
data_set['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data_set['Purchased'].unique()
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()

y = dataset['Gender']
dataset['Gender'] = label.fit_transform(y)
label.classes_
# Out:
# array([0, 1])

# %%
x = dataset.iloc[:,[2,3]].values
y = dataset.iloc[:,4].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train
x_test
# Out:
# array([[-0.40281429, -0.94975175],
#        [ 1.17992506, -0.10674686],
#        [-0.79849913, -0.4814157 ],
#        [-0.79849913, -0.10674686],
#        [ 2.23508462,  1.67293011],
#        [-0.27091935, -1.35564299],
#        [-0.40281429, -1.04341896],
#        [ 2.63076946,  1.70415251],
#        [-0.79849913, -0.01307966],
#        [ 2.10318968,  0.76748042],
#        [-0.1390244 , -1.10586376],
#        [ 1.70750484,  1.79781972],
#        [-0.40281429,  0.89237003],
#        [-0.27091935, -1.26197578],
#        [-0.00712946,  2.85938142],
#        [-0.40281429,  0.48647879],
#        [-0.79849913, -0.54386051],
#        [-0.66660419, -1.10586376],
#        [-0.79849913, -0.4501933 ],
#        [-0.27091935, -0.79363973],
#        [-0.79849913, -1.35564299],
#        [ 1.04803011,  0.23669957],
#        [ 1.44371495, -0.04430206],
#        [-0.79849913, -0.98097415],
#        [-0.79849913, -1.19953097]])

# %%
from sklearn.svm import SVC

classifier = SVC(kernel='linear',random_state=0)
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
# from matplotlib.colors import ListedColormap
# x_set,y_set = x_train,y_train

# x1,y1 = np.meshgrid(np.arange(start = x_set[:,0].min() - 1 ,))
